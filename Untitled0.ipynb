# %% [markdown]
# <a href="https://colab.research.google.com/github/SangwanJaat/Info1/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def format_name(f_name, l_name):
  if f_name=="" or l_name=="":
    return("You didn't provide valid inputs.")
  formated_f_name=f_name.title()
  formated_l_name=l_name.title()
  return f"{formated_f_name} {formated_l_name}"

print(format_name(input("What is your first name?"), input("What is your last name?")))
# Out:
# What is your first name?
# What is your last name?
# You didn't provide valid inputs.

# %%
def is_leap_year(year):
    # Write your code here.
    # Don't change the function name.
    if year%4==0:
        if year%100==0:
            if year%400==0:
                return True
            else:
                return False
        else:
            return True
    else:
        return False

#print(is_leap_year(input("Write a year you want to check is leap year or not")))'''

# %%
def format_name(f_name, l_name):
  """Take a first and last name and format it to return the title case version of the name."""
  if f_name=="" or l_name=="":
    return("You didn't provide valid inputs.")
  formated_f_name=f_name.title()
  formated_l_name=l_name.title()
  return f"{formated_f_name} {formated_l_name}"

print(format_name(input("What is your first name?"), input("What is your last name?")))

# %%
logo="""           _            _       _
          | |          | |     | |
  ___ __ _| | ___ _   _| | __ _| |_ ___  _ __
 / __/ _` | |/ __| | | | |/ _` | __/ _ \| '__|
| (_| (_| | | (__| |_| | | (_| | || (_) | |
 \___\__,_|_|\___|\__,_|_|\__,_|\__\___/|_|
                                              """

logo1=""" _____________________
|  _________________  |
| | JO           0. | |
| |_________________| |
|  ___ ___ ___   ___  |
| | 7 | 8 | 9 | | + | |
| |___|___|___| |___| |
| | 4 | 5 | 6 | | - | |
| |___|___|___| |___| |
| | 1 | 2 | 3 | | x | |
| |___|___|___| |___| |
| | . | 0 | = | | / | |
| |___|___|___| |___| |
|_____________________|"""




def add(n1,n2):
  return n1+n2

def subtract(n1,n2):
  return n1-n2

def multiply(n1,n2):
  return n1*n2

def divide(n1,n2):
  return n1/n2

operations = {"+":add,"-":subtract,"*":multiply,"/":divide}
#print(operations["*"](4,8))
def calculator():
  print(logo)
  print(logo1)
  should_accumulate=True
  num1=float(input("What is the first number?: "))
  while should_accumulate:
    for symbol in operations:
      print(symbol)
    operation_symbol=input("Pick an operation from the line above:")
    num2=float(input("What is the second number?:"))
    answer=operations[operation_symbol](num1,num2)
    print(f"{num1} {operation_symbol} {num2} = {answer}")

    choice=input(f"Type 'y' to continue calculating with {answer}, or type 'n' to start a new calculation:")
    if choice == "y":
      num1=answer
    else:
      should_accumulate=False
      print("\n"*30)
      calculator()


calculator()
# Out:
#            _            _       _
#           | |          | |     | |
#   ___ __ _| | ___ _   _| | __ _| |_ ___  _ __
#  / __/ _` | |/ __| | | | |/ _` | __/ _ \| '__|
# | (_| (_| | | (__| |_| | | (_| | || (_) | |
#  \___\__,_|_|\___|\__,_|_|\__,_|\__\___/|_|
#
#  _____________________
# |  _________________  |
# | | JO           0. | |
# | |_________________| |
# |  ___ ___ ___   ___  |
# | | 7 | 8 | 9 | | + | |
# | |___|___|___| |___| |
# | | 4 | 5 | 6 | | - | |
# | |___|___|___| |___| |
# | | 1 | 2 | 3 | | x | |
# | |___|___|___| |___| |
# | | . | 0 | = | | / | |
# | |___|___|___| |___| |
# |_____________________|
# What is the first number?: 25
# +
# -
# *
# /
# Pick an operation from the line above:*
# What is the second number?:5
# 25.0 * 5.0 = 125.0
# Type 'y' to continue calculating with 125.0, or type 'n' to start a new calculation:y
# +
# -
# *
# /
# Pick an operation from the line above:/
# What is the second number?:4
# 125.0 / 4.0 = 31.25
# Type 'y' to continue calculating with 31.25, or type 'n' to start a new calculation:n
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#            _            _       _
#           | |          | |     | |
#   ___ __ _| | ___ _   _| | __ _| |_ ___  _ __
#  / __/ _` | |/ __| | | | |/ _` | __/ _ \| '__|
# | (_| (_| | | (__| |_| | | (_| | || (_) | |
#  \___\__,_|_|\___|\__,_|_|\__,_|\__\___/|_|
#
#  _____________________
# |  _________________  |
# | | JO           0. | |
# | |_________________| |
# |  ___ ___ ___   ___  |
# | | 7 | 8 | 9 | | + | |
# | |___|___|___| |___| |
# | | 4 | 5 | 6 | | - | |
# | |___|___|___| |___| |
# | | 1 | 2 | 3 | | x | |
# | |___|___|___| |___| |
# | | . | 0 | = | | / | |
# | |___|___|___| |___| |
# |_____________________|
